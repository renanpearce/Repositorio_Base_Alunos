# %% [markdown]
# # strings

# %% [markdown]
# são usadas pricipalmente para armazenar informações de texto. nelas temos uma sequencia de caracteres que formam um texto. O phython permite formmar strings com aspas simples ou duplas

# %%
"joao"== " JOÃO" # o phython diferencia letras maiusculas de minusculas

# %%
nome = "beatriz"
sobrenome = "west"
print (nome +" " + sobrenome)
# Out:
# beatriz west

# %% [markdown]
# # f-strings

# %% [markdown]
# # string literais  formatadas

# %%
idade = 20

# %%
print (nome, sobrenome, idade) # as virgulas são maneiras de chamar variaveis diferentes
# Out:
# beatriz west 20

# %%
print ( f"o nome é {nome} {sobrenome} e sua idade é {idade} anos. ") # f na frente do print informa que estamos formatando o print
# Out:
# o nome é beatriz west e sua idade é 20 anos.

# %%
linguagem = "phython"
print (f"adoro progamar em {linguagem}. e,amo mais ainda ganhar muito $$ programando em phython. ")
# Out:
# adoro progamar em phython. e,amo mais ainda ganhar muito $$ programando em phython.

# %% [markdown]
# # SRING SÃO OBJETOS ITERÁVEIS

# %%
nome = "loren barriguda " # o phython entende uma palavra  como uma lista de letras, entao, podemos percorrer # essa lista e capturar  os elementos  que desejamos # uma lista  sempre inicia  pelo indice  zero

# %%
print( nome )
# Out:
# loren barriguda

# %%
nome[0]
# Out:
# 'l'

# %%
nome[3]
# Out:
# 'e'

# %%
nome [-1] # podemos acessar o ultimo elemento de uma lista atraves  do indice -1
# Out:
# ' '

# %% [markdown]
# # entrada de dados com função  input()

# %% [markdown]
# é muito comum em programação que o usuario passe algum  tipo de dado

# %%
input("digite seu nome: ")
# Out:
# digite seu nome: akemi
# 'akemi'

# %%
nome = input("digite seu nome: ")
# Out:
# digite seu nome: akemi

# %%
print (nome)
# Out:
# akemi

# %%
from ast import Num
# para fazer uma operacão matematica preciasmos informar qual tipo é  o dado
num1 = int(input("digite um numero: "))
num2 = int(input("digite outro numero: "))
print (num1 + num2)
# Out:
# digite um numero: 23
# digite outro numero: 79
# 102

# %%
soma = num1 + num2
print (soma)
# Out:
# 102

# %%
nota1 = float(input("digite a primeira nota : "))
nota2 = float(input("digite a segunda nota : "))
media = (nota1 + nota2)/2
print (f"o aluno teve notas {nota1}, {nota2} e sua media foi {media}")
# Out:
# digite a primeira nota : 5
# digite a segunda nota : 7
# o aluno teve notas 5.0, 7.0 e sua media foi 6.0

# %% [markdown]
# # operadores ariméticos

# %% [markdown]
# adição (+)

# %%
print (10 + 20)
print (10 + 60)
print (50 +50)
# Out:
# 30
# 70
# 100

# %%
print (17 + 4) # print () é uma função  de saída  do phython
print (30 - 20) # 30 + (-20)
print ( 50 +  40) # 30 + (67)
# Out:
# 21
# 10
# 90

# %% [markdown]
# # subtração (-)

# %%
print  ( 123 - 87)
# Out:
# 36

# %% [markdown]
# multiplicação (*)

# %%
print (10*2)
# Out:
# 20

# %%
print ( 2* 10)
# Out:
# 20

# %% [markdown]
# divisão (/)

# %%
print (1000/10)
print ( 129/13)
# Out:
# 100.0
# 9.923076923076923

# %% [markdown]
# divisão com resultado inteiro ( //)

# %%
print (129//23)
# Out:
# 5

# %% [markdown]
# exponeciação (**)

# %%
print (2**3)
# Out:
# 8

# %%
print ( 20**-2)
# Out:
# 0.0025

# %%
print (2**-1.5)
# Out:
# 0.3535533905932738

# %% [markdown]
# # precedencia

# %% [markdown]
# 1. parenteses
# 2. expoentes
# 3. multiplição ( da esquerda para a direita)
# 4. divisão (da equerda para a direita )
# 5. soma e subtração

# %%
5 + 25  * 2
# Out:
# 55

# %%
(5+25) * 2
# Out:
# 60

# %%
(12+ 3 - 1 * 50 / 3)
# Out:
# -1.6666666666666679

# %% [markdown]
# # radiciação

# %%
4  ** 0.5
# Out:
# 2.0

# %% [markdown]
# # hora da prática

# %% [markdown]
# 1) crie um código  que receba o nome do aluno  duas notas  e informe  a media do aluno
# Obs: no seu print   deve apresentar o nome do aluno   as duas notas  e a media

# %%
nota1 = float(input("digite a primeira nota : "))
nota2 = float(input("digite a segunda nota : "))
media = (nota1 + nota2)/2
print (f"a akemi teve notas {nota1}, {nota2} e sua media foi {media}")
# Out:
# digite a primeira nota : 9
# digite a segunda nota : 10
# a akemi teve notas 9.0, 10.0 e sua media foi 9.5

# %% [markdown]
# 2) crie um codigo que receba as medidas  de um retangulo e informe o perimetro do mesmo

# %%
largura1 = float(input("digite a primeira largura : "))
altura2 = float(input("digite a segunda altura : "))
perimetro = (largura1 + altura2)/2
print (f"o retangulo teve a altura e largura  {largura1}, {altura2} e seu perimetro foi {perimetro}")
# Out:
# digite a primeira largura : 10
# digite a segunda altura : 5
# o retangulo teve a altura e largura  10.0, 5.0 e seu perimetro foi 7.5

# %% [markdown]
# 3) crie um codigo que calcule a raiz quadrada de um numero

# %%
print (8 ** 3)
# Out:
# 512

# %% [markdown]
# 4) crie uma calculadora simples (adição,subtração,multiplicação,divisão)

# %%
num1 = int(input("digite um numero: "))
num2 = int(input("digite outro numero: "))
soma = num1 + num2
subtração = num1-num2
multiplicação = num1*num2
divisão = num1/num2
print (f"o resultado da soma, multiplicação, divisão,subtração, {num1}, {num2} é {soma}, {multiplicação}, {divisão}, {subtração:.2f}")
# Out:
# digite um numero: 10
# digite outro numero: 20
# o resultado da soma, multiplicação, divisão,subtração, 10, 20 é 30, 200, 0.5, -10.00

# %% [markdown]
# 5) calcule a diferença entre os dois números

# %%
num1 = float(input("digite um numero: "))
num2 = float(input("digite outro numero: "))
diferença = num1 - num2
print (f"a diferença entre {num1} e {num2} é {diferença}")
# Out:
# digite um numero: 10
# digite outro numero: 20
# a diferença entre 10.0 e 20.0 é -10.0

# %% [markdown]
# 6) calcule o produto entre dois números

# %%
num1 = float(input("digite o primeiro numero: "))
num2 = float(input("digite o segundo numero: "))
quociente = num1 * num2
print (f"o quociente entre {num1} e {num2} é {quociente}")
# Out:
# digite o primeiro numero: 10
# digite o segundo numero: 20
# o quociente entre 10.0 e 20.0 é 200.0

# %% [markdown]
# 7) crie um código que receba uma base e depois um expoente e calcule a potencia

# %%
num1 = float(input("digite o primeiro numero: "))
num2 = float(input("digite o segundo numero: "))
potencia = num1 ** num2
print (f"a potencia entre {num1} e {num2} é {potencia}")
# Out:
# digite o primeiro numero: 10
# digite o segundo numero: 20
# a potencia entre 10.0 e 20.0 é 1e+20

# %% [markdown]
# 8) crie um progama que solicite ao usuario a quantidade de horas trabalhadas por semana e o valor da hora de trabalho e calcule o salario mensal

# %%
horas_trabalhadas = float(input("digite a quantidade de horas trabalhadas por semana: "))
valor_hora = float(input("digite o valor da hora de trabalho: "))
salario_mensal = horas_trabalhadas * valor_hora
# Out:
# digite a quantidade de horas trabalhadas por semana: 10
# digite o valor da hora de trabalho: 20
