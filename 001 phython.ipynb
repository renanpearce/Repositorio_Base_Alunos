# %% [markdown]
# # tutorial variáveis

# %% [markdown]
# ## oque são vareáveis

# %% [markdown]
# vareáveis são espaços da memória do computador onde podemos guardar informações (como textos, numeros, resultados de calculos, etc) para usar depois.

# %% [markdown]
# variável com texto (string)

# %%
nome ='chad'
print (nome)
# Out:
# chad

# %%
nome= 'loren'

# %%
print (nome)
# Out:
# chad

# %% [markdown]
# ## váriavel com número inteiro (int)

# %%
idade =  16
print (idade)
# Out:
# 16

# %%
# este é um exemplo de número inteiro negativo
temperatura = -3 # está variável está armazenando um número negativo
print (temperatura) # print () é uma função de saída
# Out:
# -3

# %% [markdown]
# ## variável com número decimal (float)

# %%
altura = 1.62 # em phython os números deciamis são  escritos com ".", = 5.2
print (altura)
# Out:
# 1.62

# %%
pi= 3.14
print (pi)
# Out:
# 3.14

# %% [markdown]
# ## variável com valor booleano (bool)

# %%
estudante = True
print (estudante)
# Out:
# True

# %% [markdown]
# ## nomes Variáveis

# %% [markdown]
# * começar com letra exemplos
# ( n, numero, a
# * conter numeros mas não pode comecar com numeros exemplos n1, numero1, etc)
#
# não pode:
#
# *   comecar com numero
# *   usar espaço
# ( nome_completo, nome-completo, nomecompleto)
# *   usar acentuação ou caracteres especiais
# ( %,&,$,@)
# *   usar palavras reservadas

# %%
# errado
1idade= 16 #comecar com numero
meu nome  =  "bindilin"  # espaco  não e permetido

# %% [markdown]
# ##  o que é snake_case?

# %% [markdown]
# snake_case é um estilo de escrita usadado para nome de váriaveis, funções,e nomes em geral no código . Neste estilo, as palavras são  todas em minusculas em seperadas  por um underline (_)

# %% [markdown]
# ## Por que usar o snake_case?
#
#
# *   deixe o código mais facil de ler
# *    é o padrao recomendado  pela comunidade python
# *   segue  a  PEF8, que é o guia  de estilo oficial do phython
#
# OBS: PEF8 é um documento que recomenda  boas práticas pra escrever codigo  phython  limpo e legivel

# %% [markdown]
# ## exemplos  que não usam snake_case

# %%
nomecompleto = "julio" # estilo camelcase ( mais comum  em javascript)
nomecompleto = "julio" #  estilo pascalcase (usado para classes em phython)
nomecompleto = "julio" #  estilo dificil  de ler
